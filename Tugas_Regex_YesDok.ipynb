# %%
import pandas as pd

# Load the dataset
file_path = '/content/review_yesdok_stemming.csv'  # Replace with your actual file path
data_flexible = pd.read_csv(file_path, sep=';')

# %%
# 1. Find reviews that mention 'dokter' or 'konsultasi'
dokter_reviews = data_flexible[data_flexible['content'].str.contains(r'(dokter|konsultasi)', case=False, na=False)]
print("Reviews mentioning 'dokter' or 'konsultasi':")
dokter_reviews.head()
# Out:
# Reviews mentioning 'dokter' or 'konsultasi':
# <ipython-input-6-17dbde6a84c4>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   dokter_reviews = data_flexible[data_flexible['content'].str.contains(r'(dokter|konsultasi)', case=False, na=False)]
#                                              content  score sentiment_rating  \
# 2  sudah war jadwal dokter berbulan2 pas hari h d...      1         Negative
# 3                              dokternya sibuk terus      1         Negative
# 4  aplikasi yang sangat kurang relevan buat dipak...      1         Negative
# 7  aplikasi konsultasi dokter,dokternya ga ada yg...      1         Negative
# 9  menurut saya aplikasi tidak sesuai dengan webs...      3          Neutral
#
#    wordCount                            tweet_without_stopwords  \
# 2         60  sudah war jadwal dokter berbulan2 pas hari h d...
# 3          3                              dokternya sibuk terus
# 4         73  aplikasi yang sangat kurang relevan buat dipak...
# 7          9  aplikasi konsultasi dokter,dokternya ga ada yg...
# 9         68  menurut saya aplikasi tidak sesuai dengan webs...
#
#    wordCount_after_stopwords
# 2                         60
# 3                          3
# 4                         73
# 7                          9
# 9                         68

# %%
# 2. Find reviews that mention 'bayar' or 'transfer'
payment_reviews = data_flexible[data_flexible['content'].str.contains(r'(bayar|transfer)', case=False, na=False)]
print("Reviews mentioning 'bayar' or 'transfer':")
payment_reviews.head()
# Out:
# Reviews mentioning 'bayar' or 'transfer':
# <ipython-input-8-a81d08c04503>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   payment_reviews = data_flexible[data_flexible['content'].str.contains(r'(bayar|transfer)', case=False, na=False)]
#                                                content  score  \
# 0    gak bisa bayar yg mau di bpilih , bingung aneh...      2
# 4    aplikasi yang sangat kurang relevan buat dipak...      1
# 6    katanya 24jam, setelah transfer dari shopee se...      1
# 103  buat konsul dgn dokter recommended bgt nih res...      5
# 149  awalnya minta bayar 35rb. begitu di tambahkan ...      1
#
#     sentiment_rating  wordCount  \
# 0           Negative         15
# 4           Negative         73
# 6           Negative         38
# 103         Positive         35
# 149         Negative         17
#
#                                tweet_without_stopwords  \
# 0    gak bisa bayar yg mau di bpilih , bingung aneh...
# 4    aplikasi yang sangat kurang relevan buat dipak...
# 6    katanya 24jam, setelah transfer dari shopee se...
# 103  buat konsul dgn dokter recommended bgt nih res...
# 149  awalnya minta bayar 35rb. begitu di tambahkan ...
#
#      wordCount_after_stopwords
# 0                           15
# 4                           73
# 6                           38
# 103                         35
# 149                         17

# %%
# 3. Find reviews that mention 'tidak', 'gak', or 'susah'
negation_reviews = data_flexible[data_flexible['content'].str.contains(r'(tidak|gak|susah)', case=False, na=False)]
print("Reviews mentioning 'tidak', 'gak', or 'susah':")
negation_reviews.head()
# Out:
# Reviews mentioning 'tidak', 'gak', or 'susah':
# <ipython-input-10-d6de512c62c6>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   negation_reviews = data_flexible[data_flexible['content'].str.contains(r'(tidak|gak|susah)', case=False, na=False)]
#                                              content  score sentiment_rating  \
# 0  gak bisa bayar yg mau di bpilih , bingung aneh...      2         Negative
# 2  sudah war jadwal dokter berbulan2 pas hari h d...      1         Negative
# 4  aplikasi yang sangat kurang relevan buat dipak...      1         Negative
# 7  aplikasi konsultasi dokter,dokternya ga ada yg...      1         Negative
# 9  menurut saya aplikasi tidak sesuai dengan webs...      3          Neutral
#
#    wordCount                            tweet_without_stopwords  \
# 0         15  gak bisa bayar yg mau di bpilih , bingung aneh...
# 2         60  sudah war jadwal dokter berbulan2 pas hari h d...
# 4         73  aplikasi yang sangat kurang relevan buat dipak...
# 7          9  aplikasi konsultasi dokter,dokternya ga ada yg...
# 9         68  menurut saya aplikasi tidak sesuai dengan webs...
#
#    wordCount_after_stopwords
# 0                         15
# 2                         60
# 4                         73
# 7                          9
# 9                         68

# %%
# 4. Find reviews that mention 'bagus', 'baik', or 'puas'
positive_reviews = data_flexible[data_flexible['content'].str.contains(r'(bagus|baik|puas)', case=False, na=False)]
print("Reviews mentioning 'bagus', 'baik', or 'puas':")
positive_reviews.head()
# Out:
# Reviews mentioning 'bagus', 'baik', or 'puas':
# <ipython-input-11-7dfafa49f3c2>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   positive_reviews = data_flexible[data_flexible['content'].str.contains(r'(bagus|baik|puas)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 4   aplikasi yang sangat kurang relevan buat dipak...      1         Negative
# 6   katanya 24jam, setelah transfer dari shopee se...      1         Negative
# 9   menurut saya aplikasi tidak sesuai dengan webs...      3          Neutral
# 16  kenapa tidak keluar suara ya pas saya konsulta...      1         Negative
# 20                           karna pelayanan nya baik      5         Positive
#
#     wordCount                            tweet_without_stopwords  \
# 4          73  aplikasi yang sangat kurang relevan buat dipak...
# 6          38  katanya 24jam, setelah transfer dari shopee se...
# 9          68  menurut saya aplikasi tidak sesuai dengan webs...
# 16         68  kenapa tidak keluar suara ya pas saya konsulta...
# 20          4                           karna pelayanan nya baik
#
#     wordCount_after_stopwords
# 4                          73
# 6                          38
# 9                          68
# 16                         68
# 20                          4

# %%
# 5. Find reviews that mention 'lama' or 'lambat'
slow_reviews = data_flexible[data_flexible['content'].str.contains(r'(lama|lambat)', case=False, na=False)]
print("Reviews mentioning 'lama' or 'lambat':")
slow_reviews.head()
# Out:
# Reviews mentioning 'lama' or 'lambat':
# <ipython-input-12-cffb92c2cbdf>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   slow_reviews = data_flexible[data_flexible['content'].str.contains(r'(lama|lambat)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 2   sudah war jadwal dokter berbulan2 pas hari h d...      1         Negative
# 5   ini membantu aku mengatasi ocd tapi waktu tung...      3          Neutral
# 58  aplikasi terbaik menurut saya sangat membantu ...      5         Positive
# 67  saya pengguna lama, dan sudah beberapa kali ko...      5         Positive
# 85  nunggunya lama, akhirnya gagal konsultasi kare...      1         Negative
#
#     wordCount                            tweet_without_stopwords  \
# 2          60  sudah war jadwal dokter berbulan2 pas hari h d...
# 5          12  ini membantu aku mengatasi ocd tapi waktu tung...
# 58         36  aplikasi terbaik menurut saya sangat membantu ...
# 67         33  saya pengguna lama, dan sudah beberapa kali ko...
# 85          9  nunggunya lama, akhirnya gagal konsultasi kare...
#
#     wordCount_after_stopwords
# 2                          60
# 5                          12
# 58                         36
# 67                         33
# 85                          9

# %%
# 6. Find reviews that mention 'error', 'masalah', or 'gagal'
error_reviews = data_flexible[data_flexible['content'].str.contains(r'(error|masalah|gagal)', case=False, na=False)]
print("Reviews mentioning 'error', 'masalah', or 'gagal':")
error_reviews.head()
# Out:
# Reviews mentioning 'error', 'masalah', or 'gagal':
# <ipython-input-13-e575ae528a01>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   error_reviews = data_flexible[data_flexible['content'].str.contains(r'(error|masalah|gagal)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 10  kondisi saat ini kualitas udara relatif menjad...      5         Positive
# 56  alhamdulillah luar biasa sekali mengikuti ig l...      5         Positive
# 73  keren sekali aplikasi ini.. apalagi pada saat ...      5         Positive
# 83  wah seru banget sih live yang diadain yesdok s...      5         Positive
# 85  nunggunya lama, akhirnya gagal konsultasi kare...      1         Negative
#
#     wordCount                            tweet_without_stopwords  \
# 10         19  kondisi saat ini kualitas udara relatif menjad...
# 56         33  alhamdulillah luar biasa sekali mengikuti ig l...
# 73         31  keren sekali aplikasi ini.. apalagi pada saat ...
# 83         41  wah seru banget sih live yang diadain yesdok s...
# 85          9  nunggunya lama, akhirnya gagal konsultasi kare...
#
#     wordCount_after_stopwords
# 10                         19
# 56                         33
# 73                         31
# 83                         41
# 85                          9

# %%
# 7. Find reviews that mention 'rekomendasi' or 'senang'
recommendation_reviews = data_flexible[data_flexible['content'].str.contains(r'(rekomendasi|senang)', case=False, na=False)]
print("Reviews mentioning 'rekomendasi' or 'senang':")
recommendation_reviews.head()
# Out:
# Reviews mentioning 'rekomendasi' or 'senang':
# <ipython-input-14-b69ad5396b0d>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   recommendation_reviews = data_flexible[data_flexible['content'].str.contains(r'(rekomendasi|senang)', case=False, na=False)]
#                                                content  score  \
# 175  proses log in mudah, bisa konsultasi dengan ah...      4
# 185  sangat bermanfaat dan bagus banget bisa vidio ...      5
# 187  mengesalkan, saya sakit butuh obat segera tanp...      1
# 233  dengan aplikasi yesdok yang mudah digunakan su...      5
# 317  saya selalu rekomendasikan yesdok ke semua tem...      5
#
#     sentiment_rating  wordCount  \
# 175         Positive         63
# 185         Positive         22
# 187         Negative         73
# 233         Positive         17
# 317         Positive          8
#
#                                tweet_without_stopwords  \
# 175  proses log in mudah, bisa konsultasi dengan ah...
# 185  sangat bermanfaat dan bagus banget bisa vidio ...
# 187  mengesalkan, saya sakit butuh obat segera tanp...
# 233  dengan aplikasi yesdok yang mudah digunakan su...
# 317  saya selalu rekomendasikan yesdok ke semua tem...
#
#      wordCount_after_stopwords
# 175                         63
# 185                         22
# 187                         73
# 233                         17
# 317                          8

# %%
# 8. Find reviews that mention 'fitur' or 'menu'
feature_reviews = data_flexible[data_flexible['content'].str.contains(r'(fitur|menu)', case=False, na=False)]
print("Reviews mentioning 'fitur' or 'menu':")
feature_reviews.head()
# Out:
# Reviews mentioning 'fitur' or 'menu':
# <ipython-input-15-5adab11e97c6>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   feature_reviews = data_flexible[data_flexible['content'].str.contains(r'(fitur|menu)', case=False, na=False)]
#                                                content  score  \
# 9    menurut saya aplikasi tidak sesuai dengan webs...      3
# 14   recommended sekali aplikasinya ,fiturnya lengk...      5
# 18   mantap.... nih aplikasi, sayangnya cuman satu,...      5
# 58   aplikasi terbaik menurut saya sangat membantu ...      5
# 104  pilihan menu nya lengkap n mudah dimengerti, e...      5
#
#     sentiment_rating  wordCount  \
# 9            Neutral         68
# 14          Positive          9
# 18          Positive         28
# 58          Positive         36
# 104         Positive         19
#
#                                tweet_without_stopwords  \
# 9    menurut saya aplikasi tidak sesuai dengan webs...
# 14   recommended sekali aplikasinya ,fiturnya lengk...
# 18   mantap.... nih aplikasi, sayangnya cuman satu,...
# 58   aplikasi terbaik menurut saya sangat membantu ...
# 104  pilihan menu nya lengkap n mudah dimengerti, e...
#
#      wordCount_after_stopwords
# 9                           68
# 14                           9
# 18                          28
# 58                          36
# 104                         19

# %%
# 9. Find reviews that mention 'aplikasi' or 'app'
app_reviews = data_flexible[data_flexible['content'].str.contains(r'(aplikasi|app)', case=False, na=False)]
print("Reviews mentioning 'aplikasi' or 'app':")
app_reviews.head()
# Out:
# Reviews mentioning 'aplikasi' or 'app':
# <ipython-input-16-fb47e5631684>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   app_reviews = data_flexible[data_flexible['content'].str.contains(r'(aplikasi|app)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 4   aplikasi yang sangat kurang relevan buat dipak...      1         Negative
# 7   aplikasi konsultasi dokter,dokternya ga ada yg...      1         Negative
# 9   menurut saya aplikasi tidak sesuai dengan webs...      3          Neutral
# 11   aplikasi yg bermanfaat dan membantu disaat sakit      5         Positive
# 14  recommended sekali aplikasinya ,fiturnya lengk...      5         Positive
#
#     wordCount                            tweet_without_stopwords  \
# 4          73  aplikasi yang sangat kurang relevan buat dipak...
# 7           9  aplikasi konsultasi dokter,dokternya ga ada yg...
# 9          68  menurut saya aplikasi tidak sesuai dengan webs...
# 11          7   aplikasi yg bermanfaat dan membantu disaat sakit
# 14          9  recommended sekali aplikasinya ,fiturnya lengk...
#
#     wordCount_after_stopwords
# 4                          73
# 7                           9
# 9                          68
# 11                          7
# 14                          9

# %%
# 10. Find reviews that mention 'layanan', 'respon', or 'cs'
service_reviews = data_flexible[data_flexible['content'].str.contains(r'(layanan|respon|cs)', case=False, na=False)]
print("Reviews mentioning 'layanan', 'respon', or 'cs':")
service_reviews.head()
# Out:
# Reviews mentioning 'layanan', 'respon', or 'cs':
# <ipython-input-17-fc5e5cbfe812>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   service_reviews = data_flexible[data_flexible['content'].str.contains(r'(layanan|respon|cs)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 4   aplikasi yang sangat kurang relevan buat dipak...      1         Negative
# 6   katanya 24jam, setelah transfer dari shopee se...      1         Negative
# 20                           karna pelayanan nya baik      5         Positive
# 46  thanks untuk apk yesdok emang bener² membantu ...      5         Positive
# 58  aplikasi terbaik menurut saya sangat membantu ...      5         Positive
#
#     wordCount                            tweet_without_stopwords  \
# 4          73  aplikasi yang sangat kurang relevan buat dipak...
# 6          38  katanya 24jam, setelah transfer dari shopee se...
# 20          4                           karna pelayanan nya baik
# 46         48  thanks untuk apk yesdok emang bener² membantu ...
# 58         36  aplikasi terbaik menurut saya sangat membantu ...
#
#     wordCount_after_stopwords
# 4                          73
# 6                          38
# 20                          4
# 46                         48
# 58                         36
